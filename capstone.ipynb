# %% [markdown]
# <h1 span style="color:red">This note book used for capstone project
#
# <h4 span style="color:blue">will create my capstone project here

# %%
import pandas as pd
import numpy as np

# %%
print("hello capstone project")
# Out:
# hello capstone project
